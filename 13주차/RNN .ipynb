# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://github.com/MyungKyuYi/AI-class/raw/refs/heads/main/AAME.csv')
df = df.sort_values('Date')
df.head()
# Out:
#          Date  Open  High   Low  Close  Adj Close  Volume
# 0  1980-03-17   0.0  4.05  3.85   3.85   3.213167   15000
# 1  1980-03-18   0.0  4.00  3.80   3.80   3.171437   10200
# 2  1980-03-19   0.0  4.05  3.85   3.85   3.213167   33500
# 3  1980-03-20   0.0  4.00  3.80   3.80   3.171437    8700
# 4  1980-03-21   0.0  3.95  3.75   3.75   3.129709   12700

# %%
df = df.drop(['Date', 'Volume', 'Adj Close'], axis=1)

# %%
df.isnull().sum()
# Out:
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# %%
def split_sequence(data, window_size):
    X, y = [], [] # X: 60일간의 Open, High, Low, Close값, y: 다음 날의 Close 값

    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size, 3])

    return np.array(X), np.array(y)

# %%
X, y = split_sequence(scaled_data, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
model = Sequential([
    SimpleRNN(50, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/20
# 227/227 [==============================] - 3s 7ms/step - loss: 0.0014 - val_loss: 4.5359e-05
# Epoch 2/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.6820e-04 - val_loss: 5.2851e-05
# Epoch 3/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.4713e-04 - val_loss: 3.2877e-05
# Epoch 4/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.3625e-04 - val_loss: 3.7623e-05
# Epoch 5/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.2663e-04 - val_loss: 2.7669e-05
# Epoch 6/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.2229e-04 - val_loss: 2.3979e-05
# Epoch 7/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.4203e-04 - val_loss: 2.7476e-05
# Epoch 8/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.1733e-04 - val_loss: 2.2584e-05
# Epoch 9/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.0845e-04 - val_loss: 2.9141e-05
# Epoch 10/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.2562e-04 - val_loss: 2.2619e-05
# Epoch 11/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.1260e-04 - val_loss: 2.1260e-05
# Epoch 12/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.1013e-04 - val_loss: 2.0357e-05
# Epoch 13/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.0765e-04 - val_loss: 2.2161e-05
# Epoch 14/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.1245e-04 - val_loss: 2.1743e-05
# Epoch 15/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.0389e-04 - val_loss: 2.5039e-05
# Epoch 16/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.0195e-04 - val_loss: 2.5721e-05
# Epoch 17/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.0296e-04 - val_loss: 3.4627e-05
# Epoch 18/20
# 227/227 [==============================] - 1s 5ms/step - loss: 9.9518e-05 - val_loss: 2.0708e-05
# Epoch 19/20
# 227/227 [==============================] - 1s 5ms/step - loss: 9.8052e-05 - val_loss: 2.0783e-05
# Epoch 20/20
# 227/227 [==============================] - 1s 5ms/step - loss: 1.0469e-04 - val_loss: 2.1514e-05

# %%
y_pred = model.predict(X_test)

def inverse_transform_close(y_scaled):
    dummy = np.zeros((len(y_scaled), 4))
    dummy[:, 3] = y_scaled
    return scaler.inverse_transform(dummy)[:, 3]

real_close = inverse_transform_close(y_test)
pred_close = inverse_transform_close(y_pred.flatten())

plt.figure(figsize=(14, 6))
plt.plot(real_close, label='Real Close')
plt.plot(pred_close, label='RNN Predicted Close')
plt.legend()
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.show()
# Out:
# 64/64 [==============================] - 1s 3ms/step
